# %%
import pandas as pd
#import opencv as cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# To read the data set.
data = pd.read_csv('/home/soniya/Documents/work/netflix_titles.csv')

# %%
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
# Shows top four results.
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
# Shows last four.
data.tail()
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %%
# Gives all information about the data.
data.info
# Out:
# <bound method DataFrame.info of        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# ...

# %%
# Shows numerical data.
data.describe()
# Out:
#             show_id  release_year
# count  6.234000e+03    6234.00000
# mean   7.670368e+07    2013.35932
# std    1.094296e+07       8.81162
# min    2.477470e+05    1925.00000
# 25%    8.003580e+07    2013.00000
# 50%    8.016337e+07    2016.00000
# 75%    8.024489e+07    2018.00000
# max    8.123573e+07    2020.00000

# %%
# To show a particular column.
data['type']
# Series
# Out:
# 0         Movie
# 1         Movie
# 2       TV Show
# 3       TV Show
# 4         Movie
#          ...
# 6229    TV Show
# 6230    TV Show
# 6231      Movie
# 6232    TV Show
# 6233    TV Show
# Name: type, Length: 6234, dtype: object

# %%
# Shows top four names of type column.
data['type'].head()
# Out:
# 0      Movie
# 1      Movie
# 2    TV Show
# 3    TV Show
# 4      Movie
# Name: type, dtype: object

# %%
# Here there has been no change in the data..in fact a new data (i.e.movie_data) set has been created with type-'Movie'.
movie_data = data[data['type'] == 'Movie']
movie_data
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     80117401  Movie               Jandino: Whatever it Takes
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...        ...    ...                                      ...
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
# 6231  80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# ...

# %%
# This is to remove NaN.
movie_data.dropna(subset = ['director'])
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990  Movie                              Good People
# ...        ...    ...                                      ...
# 5575  80093107  Movie                                     Toro
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...

# %%
# To add column of our own.
# Test is the heading of the new column.
data['Test'] = np.nan
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
data.dropna(axis = 1,how = 'all')
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
# Set_index
new = movie_data.set_index('show_id')
new
# Out:
#            type                                    title  \
# show_id
# 81145628  Movie  Norm of the North: King Sized Adventure
# 80117401  Movie               Jandino: Whatever it Takes
# 80125979  Movie                             #realityhigh
# 70304989  Movie                                 Automata
# 80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...         ...                                      ...
# 80085438  Movie                          Frank and Cindy
# 80085439  Movie                          Frank and Cindy
# 80011846  Movie                                  Iverson
# 80064521  Movie      Jeremy Scott: The People's Designer
# 80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                                  director  \
# show_id
# 81145628         Richard Finn, Tim Maltby
# 80117401                              NaN
# 80125979                 Fernando Lebrija
# 70304989                      Gabe Ibáñez
# 80164077  Rodrigo Toro, Francisco Schultz
# ...

# %%
movie_data['duration']
# Out:
# 0        90 min
# 1        94 min
# 4        99 min
# 6       110 min
# 7        60 min
#          ...
# 5577     70 min
# 5578    102 min
# 5579     88 min
# 5580    109 min
# 6231     60 min
# Name: duration, Length: 4265, dtype: object

# %%
# This is for data manipulation.
# Here we replace 'min' with ''.
L = movie_data['duration'].tolist()
new_L = []
j = 0
for i in L:
    j = i.replace('min', '')
    new_L.append(j)
    
# This is to convert the string data type to int data type.
    new_L = list(map(int,new_L))
new_L
# Or the last line can be done using the map function.
# new_L = list(map(int, new_L))
# Out:
# [90,
#  94,
#  99,
#  110,
#  60,
#  90,
#  78,
#  95,
#  58,
#  62,
#  65,
#  61,
#  65,
#  58,
#  60,
#  135,
#  98,
#  96,
#  79,
#  113,
#  90,
#  80,
#  77,
#  112,
#  106,
#  106,
#  102,
#  114,
#  125,
#  142,
#  133,
#  100,
#  86,
#  146,
#  79,
#  102,
#  10,
#  122,
#  126,
#  116,
#  135,
#  125,
#  96,
#  130,
#  98,
#  70,
#  128,
#  88,
#  108,
#  93,
#  135,
#  88,
#  64,
#  107,
#  130,
#  92,
#  96,
#  112,
#  111,
#  103,
#  40,
#  103,
#  85,
#  72,
#  45,
#  89,
#  90,
#  126,
#  130,
#  126,
#  24,
#  127,
#  108,
#  163,
#  117,
#  106,
#  102,
#  116,
#  42,
#  95,
#  104,
#  75,
#  133,
#  108,
#  103,
#  82,
#  94,
#  100,
#  38,
#  97,
#  89,
#  146,
#  146,
#  130,
#  110,
#  81,
#  91,
#  106,
#  58,
#  111,
#  112,
#  102,
#  152,
#  87,
#  99,
#  78,
#  121,
#  91,
#  101,
#  101,
#  119,
#  83,
#  182,
#  106,
#  102,
#  98,
#  124,
#  63,
#  83,
#  82,
#  111,
#  24,
#  102,
#  103,
#  87,
#  100,
#  116,
#  139,
#  101,
#  130,
#  171,
#  84,
# ...

# %%
import datetime as dt

# %%
# Here through this we have changed the format of date.
movie_data['date_added'] = pd.to_datetime(movie_data['date_added'])
# Out:
# /home/soniya/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
movie_data
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     80117401  Movie               Jandino: Whatever it Takes
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...        ...    ...                                      ...
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
# 6231  80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# ...

# %%
# Returns the different unique data of the particular column. 
data['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
movie_data['duration_usable'] = new_L
# Out:
# /home/soniya/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
movie_data['duration_usable'].plot();

# %%
movie_data['duration_usable'].mean()
# Out:
# 99.10082063305978

# %%
movie_data['duration_usable'].sum()
# Out:
# 422665
